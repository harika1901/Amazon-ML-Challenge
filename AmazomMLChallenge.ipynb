# %%
# !wget https://s3-ap-southeast-1.amazonaws.com/he-public-data/datasetb2d9982.zip -O data.zip
# !unzip data.zip
# Out:
# --2023-11-07 15:55:36--  https://s3-ap-southeast-1.amazonaws.com/he-public-data/datasetb2d9982.zip
# Resolving s3-ap-southeast-1.amazonaws.com (s3-ap-southeast-1.amazonaws.com)... 52.219.124.178, 52.219.129.92, 52.219.132.118, ...
# Connecting to s3-ap-southeast-1.amazonaws.com (s3-ap-southeast-1.amazonaws.com)|52.219.124.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 895569552 (854M) [binary/octet-stream]
# Saving to: ‘data.zip’
#
# data.zip            100%[===================>] 854.08M  16.9MB/s    in 53s
#
# 2023-11-07 15:56:31 (16.0 MB/s) - ‘data.zip’ saved [895569552/895569552]
#
# Archive:  data.zip
#    creating: dataset/
#   inflating: dataset/sample_submission.csv
#   inflating: dataset/train.csv
#   inflating: dataset/test.csv

# %%
import pandas as pd
train_data=pd.read_csv("/content/dataset/train.csv")
train_data=train_data.dropna()

train_data=train_data.iloc[:10000,:]

# %%
train_data.isnull().sum()
# Out:
# PRODUCT_ID         0
# TITLE              0
# BULLET_POINTS      0
# DESCRIPTION        0
# PRODUCT_TYPE_ID    0
# PRODUCT_LENGTH     0
# dtype: int64

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
count=0
for i in range(10000):
  if count%1000==0:
    print('Completed: ',count)
    print(train_data["TITLE"].iloc[i])
  train_data["TITLE"].iloc[i]=nlp(str(train_data["TITLE"].iloc[i])).vector
  count+=1

count=0
for i in range(10000):
  if count%1000==0:
    print('Completed: ',count)
    print(train_data["DESCRIPTION"].iloc[i])
  train_data["DESCRIPTION"].iloc[i]=nlp(str(train_data["DESCRIPTION"].iloc[i])).vector
  count+=1

count=0
for i in range(10000):
  if count%1000==0:
    print('Completed: ',count)
    print(train_data["BULLET_POINTS"].iloc[i])
  train_data["BULLET_POINTS"].iloc[i]=nlp(str(train_data["BULLET_POINTS"].iloc[i])).vector
  count+=1
# Out:
# Completed:  0
# PRIKNIK Horn Red Electric Air Horn Compressor Interior Dual Tone Trumpet Loud Compatible with SX4
# <ipython-input-4-7680e6576ed3>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data["TITLE"].iloc[i]=nlp(str(train_data["TITLE"].iloc[i])).vector
# Completed:  1000
# AK Homes -9E84 Flashing Light Strip Funny EL Light Modified Atmosphere Strip Light
# Completed:  2000
# TOMS Classic Canvas Slip On Red 13 D(M) US
# Completed:  3000
# Rudyn Gladioli Farm ,Echeveria unguiculata
# Completed:  4000
# Twinny Zone Couple Combo Split Designs Cotton T-Shirts Full Sleeves (Men- M, Women- L, WineB- Hubby Wifey)
# Completed:  5000
# Arpana Enterprises Hard Plastic [for Girls Boys] Printed Back Cover for Oppo F19 Pro+ / Oppo A94
# Completed:  6000
# Caratglitz Designer Classic Evil Eye Bracelet Jewellery Gold and Diamond Bracelet for Women
# Completed:  7000
# Lunarable Valentines Day Wooden Dog House, Heart Shapes Forming a Love Theme and Romantic, Outdoor & Indoor Portable Dog Kennel with Pillow and Cover, X-Large, Turquoise Pale Pink
# Completed:  8000
# BigMart? 100% Cotton Dark Black Kala Cotton Nazar Dhaga, 20 Meters Religious Black Thread - Kala Dhaga - Anant Dhaga -100% Cotton Moltadu Najar Surksha for Boys,Girls (Black (Pack of 1))
# Completed:  9000
# XTEP Men's Blue and Orange New Fashionable Synthetic Leather Upper AirMega Running Shoes (7 UK)
# Completed:  0
# Specifications: Color: Red, Material: Aluminium, Voltage: 12V, dB: 130 dB (around), Material: Aluminum Pump Head + Steel Pump Body + ABS Shell and Parts DB output: 130db Voltage: 12v Sound Type: Dual Tone Application: 12V Voltage Vehicles With Battery Above 20A Package included: 1 x Dual Tone Air Horn Compatible With SX4
# <ipython-input-4-7680e6576ed3>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data["DESCRIPTION"].iloc[i]=nlp(str(train_data["DESCRIPTION"].iloc[i])).vector
# Completed:  1000
# 9E84 Flashing Light Strip Funny EL Light Modified Atmosphere Strip Light, New & Imported item. Delivers within 3 to 5 weeks
# Completed:  2000
# Well paired with any clothes and can be worn for any occasion. Best choice for versatile use
# Completed:  3000
# Echeveria unguiculata is a decorative, small, rosette-forming succulent plant that can grow up to 10 cm in diameter. The leaves are curved, lanceolate and narrow, up to 5 cm long and 1 cm wide, gray with violet shading and small red or black tip. The stem is up to 2 inches long. The flowers are pink to orange (outside) and orange (inside) on a 50 cm long stem.
# Completed:  4000
# Perfect Gift for him and her, your loved ones, Couples, Love Birds, Girlfriends, boyfriends, Husband Wife. Anniversary Gifts, Gifts for Men and women, Couple Tshirts Combo, Lovers Tshirts Valentine day. Premium Cotton Split Design combo Casual Full Sleeves t-shirts for Lovers which are made of soft & smooth material with a high thread-count. Premium Combos for Best Pre Wedding Shoots. Suitable for Outings and Adventure. Comfortable and durable Casual Wear. Men Women Fashion. Our unisex combo t-shirts are available in -XS, S, M, L, XL, perfect Length. Indian Manufactured and Printed.
# Completed:  5000
# Give a new style to your phone with this designer cover from the house of Arpana Enterprises Mobile Accessories. This cover has been designed to be used on Oppo F19 Pro+ / Oppo A94 smartphone. Made from plastic, this solid back cover has a sturdy and attractive design in multy color.
# Completed:  6000
# Product Size : Length - 7.25 inch | Width - 7.3 mm | Height - 8.8 mm | Purity - 22 K | Approx.Weight - 1.48 g | Set in 22 K Yellow Gold(1.48 g) with IGLI Certified Diamonds (0.12 Ct ,IJ-SI)
# Completed:  7000
:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data["BULLET_POINTS"].iloc[i]=nlp(str(train_data["BULLET_POINTS"].iloc[i])).vector
# Completed:  1000
# [New & Imported item. Delivers within 3 to 5 weeks,Condition- New,Color as shown,Pac includes 1 pcs only]
# Completed:  2000
# [Designed with quality and comfortable in mind,Perfect fit and stylish for any occasion,Durable for all seasons]
# Completed:  3000
# [Planting Media: Use soilrite mix thoroughly mixed with sand and pebbles (1-1.5cm). The soil mixture must be well drained.,Water: The best way to water succulents is with the “soak and dry” method. Soak the soil completely then let the soil dry out completely before watering again. Make sure the succulents are in a well draining soil in a pot with a drainage hole.,For indoor succulents, it is generally best if water doesn’t get on top of the leaves. If it sits on a leaf for too long it can cause rot. This isn’t as much of an issue for outdoor succulents because there is more airflow and the water will dry out quicker.,Sunlight: It prefers full sunlight to partial shade.]
# Completed:  4000
# [Couple cool Split Design T-shirts Full Sleeve Premium Cotton Double Tone Casual combo.,Premium Combo Outfit for Best Pre Wedding Shoots and Outings.,Cute Designs that are- Durable, Highly Resistant and fade proof guaranteed.,Designed For Trendy Couples, Sure to stand out no matter where you go.,There's no reason to delay adding this combo to your wardrobe.]
# Completed:  5000
# [Designer cover case. Beautiful and Tough. Use this case to reduce the chance of breakage.,Fix perfectly around the inner shell to absorb impact form drops bumps and shocks.,Complete access to all features of the device including microphone, speaker, camera and all buttons. Enhance the appearance of the overall phone.,Easy to install and uninstall,For Oppo F19 Pro+ / Oppo A94]
# Completed:  6000
# [This bracelet is made of 22KT Yellow Gold,BIS hallmarked.BIS Hallmark is NOT a separate certificate, it is an inscription made on the product,Adorned with real diamond.The diamond is certified and has an IGL/IGLI certificate,Product Size : Length - 7.25 inch | Width - 7.3 mm | Height - 8.8 mm | Purity - 22 K | Approx.Weight - 1.48 g | Set in 22 K Yellow Gold(1.48 g) with IGLI Certified Diamonds (0.12 Ct ,IJ-SI),The weight of gold mentioned is an approximation.There may be a minute(negligible) variation upon actual manufacturing. Product colour may slightly vary due to photographic lighting sources or your monitor settings]
# Completed:  7000
# [Measurements - 35.5" X 50" X 41" Wooden Frame and 38.5"X 52" Cushion Cover. House for your lovely friends.,Made from - Utmost comfort and premium quality with durable wooden frame and soft fiber filling pillow.,Features - Cloth parts can be easily detached with hook and loop fastener. You can also use the pillow separately.,Machine Washable - Cloths parts can be washed. Durable enough for both indoor and outdoor use.,Printed - With state of the art digital printing technology. Fabrics are printed on the front side only.]
# Completed:  8000
# [Fine pure cotton nazar dhaga Once knotted will remain intact on babys hands It will never loose its color,Best thread to be used for tabeez, nazar battu , jewellery making thread.,Nazar Battu Kala Dhaaga Threads , Before wearing this thread Offer it to hanuman temple. It will make thread even more effective.,Usage:Holy Hindu Puja Ceremony, Havan Yagya and Pooja Samagri,100% SKIN FRIENDLY]
# Completed:  9000
# [Advanced Air Mega Technology For Better Running Experience : The Shock Absorbing System Is Made Up Of Air Cushions To Form The Air Mega, It Provide Runners All Around Cushioning And Support. These Running Shoes For Men Is Made For Marathons And Other Sports Activities.<Br>,Stylish Synthetic Leather Upper Ensures Flawless Breathability : Xtep Running Shoes For Mens Sport Is Fabricated With Synthetic Leather And High Quality Textile Materials Which Is Very Durable And Breathable. It Keeps Your Feet Cool & Dry Even When Your Run Heats Up. Advanced Lacing System Holded By Elasticated Loops Are Providing Stability And Support To The Sports Running Shoes.<Br>,Air Cushioning Sole Design : Air Cushioning Airmega Outsole Provides Lightweight Response And Lasting Durability. The Latest Outsole Design Enhance Reliable Traction.; Suits For Multi-Purpose Activities : The Sports Shoes For Men Branded Matches With Your Sports Lifestyle. It Is Suits For Jogging, Runnning, Outdoor And Other Sports Activities.<Br>,Care Instructions : Special Technical Fibers Are Used To Achieve Performance Characteristics Of Footwear, So Need Special Laundry Care To Enhance The Life Span Of The Shoes, Avoid Washing,Recommending Hand Wash, Do Not Twist, Pull Or Drag Shoes, It May Cause A Reduction In Product Performance Or May Damage The Technical Structure Of The Product.<Br>,Age Range Description: Adult]

# %%
train_data.to_csv('output_dataset.csv', index=False)
train_data.head()
# Out:
#    PRODUCT_ID                                              TITLE  \
# 2     2765088  [-0.120817296, -0.6034473, 0.18210436, 0.39672...
# 3     1594019  [-0.30172753, -0.32829326, -0.26941085, 0.1988...
# 5     2152929  [-0.26320964, -0.486768, -0.26648563, 0.552244...
# 7     2026580  [-0.408034, -0.5665321, -0.44239488, 0.0662604...
# 9     2998633  [-0.2259436, -0.45449623, -0.28332806, 0.28095...
#
#                                        BULLET_POINTS  \
# 2  [-0.056971382, -0.398389, 0.1772821, 0.0717490...
# 3  [-0.06048255, -0.29669142, -0.07257859, 0.0846...
# 5  [0.112959474, -0.29354924, 0.045245305, -0.016...
# 7  [0.028209824, -0.3205527, 0.064783745, 0.02600...
# 9  [0.12393233, -0.1832851, -0.30621356, 0.077562...
#
#                                          DESCRIPTION  PRODUCT_TYPE_ID  \
# 2  [-0.2089277, -0.31105655, -0.29244918, 0.13836...             7537
# 3  [-0.17939621, -0.38716075, 0.16399534, 0.09791...             2996
# 5  [0.039914962, -0.22128348, 0.021789834, -0.006...             5725
# 7  [0.0662049, -0.34979975, -0.03238398, -0.04404...             6030
# 9  [-0.022112051, -0.16617824, -0.22733752, 0.024...             8201
#
#    PRODUCT_LENGTH
# 2      748.031495
# 3      787.401574
# 5      950.000000
# 7      984.251967
# 9      393.700787

# %%
print("PRODUCT_ID: ",train_data["PRODUCT_ID"].nunique())
print("PRODUCT_TYPE_ID: ",train_data["PRODUCT_TYPE_ID"].nunique())
print("PRODUCT_LENGTH: ",train_data["PRODUCT_LENGTH"].nunique())
# Out:
# PRODUCT_ID:  10000
# PRODUCT_TYPE_ID:  2416
# PRODUCT_LENGTH:  1248
